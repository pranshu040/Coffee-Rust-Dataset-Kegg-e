tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7273.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3893.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/843.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1913.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4033.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4653.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6233.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5653.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6313.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5563.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4073.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2723.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6483.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/623.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1673.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3473.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/853.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6973.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/793.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3943.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/903.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5243.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4803.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6083.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2363.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7173.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/8063.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/363.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2563.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6803.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3793.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3223.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/813.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1273.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2123.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3883.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7393.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2963.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/153.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3903.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6743.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/33.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5413.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4453.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/133.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1953.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1873.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1733.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5173.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4713.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5303.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2813.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/573.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/873.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4603.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1763.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3913.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/663.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/263.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6523.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4723.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2973.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2543.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3353.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5843.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7673.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1043.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2053.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2613.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3343.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/8173.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6543.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3463.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2423.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7233.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2273.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1743.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3823.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/443.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2113.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1073.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1773.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3983.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7943.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2233.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/213.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/53.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5943.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7213.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3743.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7293.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3163.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4343.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1923.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4903.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2783.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2453.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5033.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3853.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4003.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2393.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7983.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5683.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3613.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4283.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4923.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7363.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1483.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1623.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3283.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5463.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5473.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4023.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1863.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2753.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6653.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1303.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2633.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1843.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7573.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2763.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/253.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/73.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1703.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5603.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7263.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1253.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1633.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4773.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3043.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5043.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1213.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2793.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3523.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5813.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1003.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3093.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4593.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3023.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/8163.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6983.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/43.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3783.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/8073.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6273.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2833.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/483.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1663.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6563.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2583.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/1263.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6383.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/2203.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5713.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/3663.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/313.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7403.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5023.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/433.TIF
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/7643.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/4473.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6623.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/5203.tif
# /kaggle/input/new-coffee-11/coffee_augmented/redband/norust/6773.tif

# %%
#!pip install imagecodecs

# %%
# !pip install tensorflow tifffile opencv-python
import tifffile as tiff
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.11/dist-packages (2025.6.11)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<2.1.0,>=1.26.0->tensorflow) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<2.1.0,>=1.26.0->tensorflow) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<2.1.0,>=1.26.0->tensorflow) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
import os
import numpy as np
import cv2
import tifffile as tiff
from tqdm import tqdm

# ==== CONFIG ====
DATA_DIR = "/kaggle/input/new-coffee-11/coffee_augmented"
LABELS = ["norust", "rust"]
IMAGE_SIZE = (224, 224)  # Resize image
GREEN_BAND_FOLDER = "greenband"  # ✅ Folder name for Green band

def load_green_band_dataset():
    X, y = [], []

    for label_idx, label in enumerate(LABELS):
        band_path = os.path.join(DATA_DIR, GREEN_BAND_FOLDER, label)
        if not os.path.exists(band_path):
            raise FileNotFoundError(f"[ERROR] Folder not found: {band_path}")

        files = [f for f in os.listdir(band_path) if f.lower().endswith(".tif")]
        print(f"\n{label.upper()} — Found {len(files)} Green band images")

        for f in tqdm(files, desc=f"Loading {label}"):
            try:
                img_path = os.path.join(band_path, f)
                img = tiff.imread(img_path)
                img = cv2.resize(img, IMAGE_SIZE)
                img = img.astype(np.float32).reshape(IMAGE_SIZE[0], IMAGE_SIZE[1], 1)  # Add channel dimension

                X.append(img)
                y.append(label_idx)

            except Exception as e:
                print(f"[ERROR] Skipping file {f}: {e}")

    print(f"\n✅ Finished loading: {len(X)} Green band images total.")
    return np.array(X, dtype=np.float32), np.array(y)

# === Load Dataset ===
X_green, y_green = load_green_band_dataset()
print("✅ Final dataset shape:", X_green.shape, y_green.shape)  # Expecting: (num_images, 224, 224, 1), (num_images,)
# Out:
# NORUST — Found 819 Green band images
# Loading norust: 100%|██████████| 819/819 [00:01<00:00, 763.51it/s]
# RUST — Found 848 Green band images
# Loading rust: 100%|██████████| 848/848 [00:01<00:00, 801.90it/s]
# ✅ Finished loading: 1667 Green band images total.
# ✅ Final dataset shape: (1667, 224, 224, 1) (1667,)

# %%
import os
import numpy as np
import cv2
import tifffile as tiff
from tqdm import tqdm

# ==== CONFIG ====
DATA_DIR = "/kaggle/input/new-coffee-11/coffee_augmented"
LABELS = ["norust", "rust"]
IMAGE_SIZE = (224, 224)  # Resize image before NDVI computation
SELECTED_BANDS = [3, 5]  # Red, NIR

BAND_FOLDERS = {
    0: "rgb",
    1: "blueband",
    2: "greenband",
    3: "redband",
    4: "rededgeband",
    5: "nir"
}

def compute_ndvi_image(red, nir):
    # Compute NDVI = (NIR - Red) / (NIR + Red)
    ndvi = (nir - red) / (nir + red + 1e-6)
    ndvi = np.clip(ndvi, -1, 1)
    return ndvi.reshape(IMAGE_SIZE[0], IMAGE_SIZE[1], 1)  # Add channel dimension

def load_ndvi_dataset():
    X, y = [], []

    for label_idx, label in enumerate(LABELS):
        band_files = {band_id: {} for band_id in SELECTED_BANDS}

        for band_id in SELECTED_BANDS:
            band_path = os.path.join(DATA_DIR, BAND_FOLDERS[band_id], label)
            if not os.path.exists(band_path):
                raise FileNotFoundError(f"[ERROR] Folder not found: {band_path}")

            for f in os.listdir(band_path):
                ext = f.lower().split('.')[-1]
                if band_id == 0 and ext not in ["jpg", "jpeg", "png"]:
                    continue
                elif band_id != 0 and ext != "tif":
                    continue

                try:
                    base = int(f.split('.')[0])
                    band_files[band_id][base] = os.path.join(band_path, f)
                except:
                    print(f"[WARN] Skipping unreadable filename: {f}")

        # Match samples across bands
        common_bases = set(k - (k % 10) for k in band_files[SELECTED_BANDS[0]].keys())
        for band_id in SELECTED_BANDS[1:]:
            common_bases &= set(k - (k % 10) for k in band_files[band_id].keys())

        print(f"\n{label.upper()} — Found {len(common_bases)} complete sample sets")

        for base in tqdm(sorted(common_bases), desc=f"Loading {label}"):
            try:
                band_images = {}
                for band_id in SELECTED_BANDS:
                    file_id = base + band_id
                    file_path = band_files[band_id].get(file_id, None)
                    if file_path is None:
                        raise FileNotFoundError(f"[MISSING] {file_id} in band {BAND_FOLDERS[band_id]}")

                    img = tiff.imread(file_path)
                    img = cv2.resize(img, IMAGE_SIZE)
                    band_images[band_id] = img.astype(np.float32)

                red = band_images[3]
                nir = band_images[5]

                ndvi_img = compute_ndvi_image(red, nir)
                X.append(ndvi_img)
                y.append(label_idx)

            except Exception as e:
                print(f"[ERROR] Skipping sample base {base}: {e}")

    print(f"\n✅ Finished loading: {len(X)} images total.")
    return np.array(X, dtype=np.float32), np.array(y)

# === Load Dataset ===
X_ndvi, y_ndvi = load_ndvi_dataset()  # From your NDVI loader
print("✅ Final dataset shape:", X_ndvi.shape, y_ndvi.shape)  # Expecting: (num_images, 224, 224, 1), (num_images,)
# Out:
# NORUST — Found 819 complete sample sets
# Loading norust: 100%|██████████| 819/819 [00:02<00:00, 381.98it/s]
# RUST — Found 848 complete sample sets
# Loading rust: 100%|██████████| 848/848 [00:02<00:00, 361.24it/s]
# ✅ Finished loading: 1667 images total.
# ✅ Final dataset shape: (1667, 224, 224, 1) (1667,)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Concatenate
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
assert len(X_green) == len(X_ndvi) == len(y_green) == len(y_ndvi), "Mismatch in dataset lengths"
assert np.array_equal(y_green, y_ndvi), "Label mismatch"

# %%
y = y_green  # or y_ndvi, since they are same

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import numpy as np

# Normalize inputs
X_green = X_green / 255.0
X_ndvi = X_ndvi / 1.0  # Already in [-1, 1]

# Convert labels to categorical
y_cat = to_categorical(y, num_classes=2)

# Step 1: Split into 80% train+val, 20% test
Xr_temp, Xr_test, Xn_temp, Xn_test, y_temp, y_test = train_test_split(
    X_green, X_ndvi, y_cat, test_size=0.2, random_state=42, stratify=y
)

# Step 2: Split 80% part into 70% train, 10% val
# 10 / 80 = 0.125 → 12.5% of train_val becomes validation
Xr_train, Xr_val, Xn_train, Xn_val, y_train, y_val = train_test_split(
    Xr_temp, Xn_temp, y_temp, test_size=0.125, random_state=42, stratify=np.argmax(y_temp, axis=1)
)

# %%
print("🔴 GREEN Band Shapes:")
print("Train:", Xr_train.shape)
print("Val:  ", Xr_val.shape)
print("Test: ", Xr_test.shape)

print("\n🌿 NDVI Shapes:")
print("Train:", Xn_train.shape)
print("Val:  ", Xn_val.shape)
print("Test: ", Xn_test.shape)

print("\n🏷️ Label Shapes:")
print("Train:", y_train.shape)
print("Val:  ", y_val.shape)
print("Test: ", y_test.shape)
# Out:
# 🔴 GREEN Band Shapes:
# Train: (1166, 224, 224, 1)
# Val:   (167, 224, 224, 1)
# Test:  (334, 224, 224, 1)
#
# 🌿 NDVI Shapes:
# Train: (1166, 224, 224, 1)
# Val:   (167, 224, 224, 1)
# Test:  (334, 224, 224, 1)
#
# 🏷️ Label Shapes:
# Train: (1166, 2)
# Val:   (167, 2)
# Test:  (334, 2)

# %%
# === Define CNN model for Red band ===
def build_green_branch(input_shape):
    input_green = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu')(input_green)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(32, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.8)(x)
    return input_green, x

# === Define CNN model for NDVI ===
def build_ndvi_branch(input_shape):
    input_ndvi = Input(shape=input_shape)
    x = Conv2D(32, (3, 3), activation='relu')(input_ndvi)
    x = MaxPooling2D((2, 2))(x)
    x = Conv2D(32, (3, 3), activation='relu')(x)
    x = MaxPooling2D((2, 2))(x)
    x = Flatten()(x)
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.8)(x)
    return input_ndvi, x

# === Combine branches ===
input_green, green_branch = build_green_branch((224, 224, 1))
input_ndvi, ndvi_branch = build_ndvi_branch((224, 224, 1))

merged = Concatenate()([green_branch, ndvi_branch])
x = Dense(128, activation='relu')(merged)
x = Dropout(0.4)(x)
output = Dense(2, activation='softmax')(x)

# Final model
model = Model(inputs=[input_green, input_ndvi], outputs=output)

# %%
from tensorflow.keras.optimizers import Adam
# Set custom learning rate
lr = 0.0001  # example value

optimizer = Adam(learning_rate=lr)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 222, 222,  │        320 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 222, 222,  │        320 │ input_layer_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 111, 111,  │          0 │ conv2d_4[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 111, 111,  │          0 │ conv2d_6[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 109, 109,  │      9,248 │ max_pooling2d_4[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 109, 109,  │      9,248 │ max_pooling2d_6[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_5     │ (None, 54, 54,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 54, 54,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_2 (Flatten) │ (None, 93312)     │          0 │ max_pooling2d_5[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten_3 (Flatten) │ (None, 93312)     │          0 │ max_pooling2d_7[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 128)       │ 11,944,064 │ flatten_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 128)       │ 11,944,064 │ flatten_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 128)       │          0 │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 256)       │          0 │ dropout_3[0][0],  │
# │ (Concatenate)       │                   │            │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │     32,896 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 128)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 2)         │        258 │ dropout_5[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,940,418 (91.33 MB)
#  Trainable params: 23,940,418 (91.33 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    [Xr_train, Xn_train], y_train,
    validation_data=([Xr_val, Xn_val], y_val),
    epochs=20,
    batch_size=32
)
# Out:
# Epoch 1/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 11s 145ms/step - accuracy: 0.5994 - loss: 0.8122 - val_accuracy: 0.7545 - val_loss: 0.5104
# Epoch 2/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.7085 - loss: 0.5698 - val_accuracy: 0.7784 - val_loss: 0.4738
# Epoch 3/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.7255 - loss: 0.5366 - val_accuracy: 0.7904 - val_loss: 0.4627
# Epoch 4/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.7400 - loss: 0.5060 - val_accuracy: 0.8084 - val_loss: 0.4321
# Epoch 5/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.7740 - loss: 0.4818 - val_accuracy: 0.8084 - val_loss: 0.4213
# Epoch 6/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.7687 - loss: 0.5285 - val_accuracy: 0.8084 - val_loss: 0.4299
# Epoch 7/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.7685 - loss: 0.4645 - val_accuracy: 0.8144 - val_loss: 0.4122
# Epoch 8/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.7966 - loss: 0.4501 - val_accuracy: 0.8144 - val_loss: 0.4035
# Epoch 9/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.8028 - loss: 0.4196 - val_accuracy: 0.8024 - val_loss: 0.4108
# Epoch 10/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.7867 - loss: 0.4473 - val_accuracy: 0.8144 - val_loss: 0.4024
# Epoch 11/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.8037 - loss: 0.4116 - val_accuracy: 0.8144 - val_loss: 0.3992
# Epoch 12/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.8254 - loss: 0.3960 - val_accuracy: 0.8204 - val_loss: 0.3981
# Epoch 13/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.8188 - loss: 0.4068 - val_accuracy: 0.8144 - val_loss: 0.3958
# Epoch 14/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.8305 - loss: 0.3772 - val_accuracy: 0.8144 - val_loss: 0.3971
# Epoch 15/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.8570 - loss: 0.3939 - val_accuracy: 0.8144 - val_loss: 0.3994
# Epoch 16/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.8239 - loss: 0.3783 - val_accuracy: 0.8144 - val_loss: 0.4049
# Epoch 17/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.8599 - loss: 0.3317 - val_accuracy: 0.8144 - val_loss: 0.3916
# Epoch 18/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.8552 - loss: 0.3244 - val_accuracy: 0.8144 - val_loss: 0.3940
# Epoch 19/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.8601 - loss: 0.3463 - val_accuracy: 0.8084 - val_loss: 0.3974
# Epoch 20/20
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - accuracy: 0.8448 - loss: 0.3576 - val_accuracy: 0.8144 - val_loss: 0.4133

# %%
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    classification_report,
    confusion_matrix,
    roc_curve
)
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

def evaluate_model(model, X_green, X_ndvi, y_true, set_name="Set"):
    # Predict probabilities
    y_pred_prob = model.predict([X_green, X_ndvi])

    # If y_true is one-hot encoded, convert to class index
    if y_true.ndim == 2 and y_true.shape[1] == 2:
        y_true = np.argmax(y_true, axis=1)

    y_pred = np.argmax(y_pred_prob, axis=1)

    # Metrics
    acc = accuracy_score(y_true, y_pred)
    prec = precision_score(y_true, y_pred)
    rec = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_pred_prob[:, 1])

    # Print metrics
    print(f"\n--- {set_name} Set Metrics ---")
    print(f"Accuracy : {acc:.4f}")
    print(f"Precision: {prec:.4f}")
    print(f"Recall   : {rec:.4f}")
    print(f"F1 Score : {f1:.4f}")
    print(f"ROC AUC  : {auc:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred, target_names=["norust", "rust"]))

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=["norust", "rust"],
                yticklabels=["norust", "rust"])
    plt.title(f"{set_name} Confusion Matrix")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

    # ROC Curve
    fpr, tpr, _ = roc_curve(y_true, y_pred_prob[:, 1])
    plt.figure(figsize=(5, 4))
    plt.plot(fpr, tpr, label=f"AUC = {auc:.2f}")
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title(f"{set_name} ROC Curve")
    plt.legend()
    plt.grid(True)
    plt.show()

# ✅ Example usage:
evaluate_model(model, Xr_train, Xn_train, y_train, set_name="Train")
evaluate_model(model, Xr_test, Xn_test, y_test, set_name="Test")
# Out:
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
#
# --- Train Set Metrics ---
# Accuracy : 0.8765
# Precision: 0.8071
# Recall   : 0.9949
# F1 Score : 0.8912
# ROC AUC  : 0.9742
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       norust       0.99      0.75      0.86       573
#         rust       0.81      0.99      0.89       593
#
#     accuracy                           0.88      1166
#    macro avg       0.90      0.87      0.87      1166
# weighted avg       0.90      0.88      0.87      1166
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# --- Test Set Metrics ---
# Accuracy : 0.8413
# Precision: 0.7721
# Recall   : 0.9765
# F1 Score : 0.8623
# ROC AUC  : 0.8836
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       norust       0.97      0.70      0.81       164
#         rust       0.77      0.98      0.86       170
#
#     accuracy                           0.84       334
#    macro avg       0.87      0.84      0.84       334
# weighted avg       0.87      0.84      0.84       334
